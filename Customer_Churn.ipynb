# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv("customer churn data set.csv")
display(df)  # display compelte table
df.sample(5)  # only 5 starting row
df.shape      # total  no of row and column
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 94  9848-JQJTX    Male              0      No         No      72          Yes
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
#
# ...

# %%
df.drop
# Out:
# <bound method DataFrame.drop of     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 94  9848-JQJTX    Male              0      No         No      72          Yes
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
#
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
  df.head()  # bwgin 5 row
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail(10)   # last10 row
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 89  3016-KSVCP    Male              0     Yes         No      29           No
# 90  4767-HZZHQ    Male              0     Yes        Yes      30          Yes
# 91  2424-WVHPL    Male              1      No         No       1          Yes
# 92  7233-PAHHL    Male              0     Yes        Yes      66          Yes
# 93  6067-NGCEU  Female              0      No         No      65          Yes
# 94  9848-JQJTX    Male              0      No         No      72          Yes
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
#
#        MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        99 non-null     object
#  1   gender            99 non-null     object
#  2   SeniorCitizen     99 non-null     int64
#  3   Partner           99 non-null     object
#  4   Dependents        99 non-null     object
#  5   tenure            99 non-null     int64
#  6   PhoneService      99 non-null     object
#  7   MultipleLines     99 non-null     object
#  8   InternetService   99 non-null     object
#  9   OnlineSecurity    99 non-null     object
#  10  OnlineBackup      99 non-null     object
#  11  DeviceProtection  99 non-null     object
#  12  TechSupport       99 non-null     object
#  13  StreamingTV       99 non-null     object
#  14  StreamingMovies   99 non-null     object
#  15  Contract          99 non-null     object
# ...

# %%
df.isnull().sum()  # check null values
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Basic Data Cleaning

# %%
df['SeniorCitizen'].dtype
# Out:
# dtype('int64')

# %%
condition=df['gender']=='Male'
selectRecord=df[condition]
display(selectRecord)
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1   5575-GNVDE   Male              0      No         No      34          Yes
# 2   3668-QPYBK   Male              0      No         No       2          Yes
# 3   7795-CFOCW   Male              0      No         No      45           No
# 6   1452-KIOVK   Male              0      No        Yes      22          Yes
# 9   6388-TABGU   Male              0      No        Yes      62          Yes
# 10  9763-GRSKD   Male              0     Yes        Yes      13          Yes
# 11  7469-LKBCI   Male              0      No         No      16          Yes
# 12  8091-TTVAX   Male              0     Yes         No      58          Yes
# 13  0280-XJGEX   Male              0      No         No      49          Yes
# 14  5129-JLPIS   Male              0      No         No      25          Yes
# 17  9959-WOFKT   Male              0      No        Yes      71          Yes
# ...

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
categorical_feature = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
     'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod',]
numerical_feature = ["tenure","MonthlyCharges","TotalCharges"]
target = "Churn"

# %%
df.skew(numeric_only=True)
# Out:
# SeniorCitizen     2.089988
# tenure            0.153845
# MonthlyCharges   -0.295276
# TotalCharges      0.889793
# dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000 -0.019794        0.216396      0.099851
# tenure              -0.019794  1.000000        0.259969      0.850799
# MonthlyCharges       0.216396  0.259969        1.000000      0.644564
# TotalCharges         0.099851  0.850799        0.644564      1.000000

# %%
df.describe()
# Out:
#        SeniorCitizen     tenure  MonthlyCharges  TotalCharges
# count      99.000000  99.000000       99.000000     99.000000
# mean        0.141414  33.050505       67.917677   2424.697475
# std         0.350222  24.591924       29.163910   2340.836332
# min         0.000000   1.000000       18.950000     20.150000
# 25%         0.000000  10.000000       49.150000    512.625000
# 50%         0.000000  30.000000       74.700000   1426.400000
# 75%         0.000000  52.000000       94.925000   4062.250000
# max         1.000000  72.000000      113.250000   7895.150000

# %%
df['tenure'].dtype

# %% [markdown]
# Feature Distribution

# %% [markdown]
# we plot distribution for numerical and categorical features to check for outliers and compare feature distribution with target variable

# %% [markdown]
# Numeric feature distribution

# %% [markdown]
# numeric summarized technique (mean,standard deviation etc.) dont show us spikes,shapes of distribution and it is hard to observe outliers with it. that is the rason we use histrogram.

# %%
df[categorical_feature].describe()

# %%
df[numeric_feature].describe()

# %%
numeric_feature=["tenure","MonthlyCharges","TotalCharges"]
display(numeric_feature)

# %%
df[numeric_feature].hist(bins=20,figsize=(10,6),edgecolor='green')

# %%
fig,ax = plt.subplots(1,3,figsize=(14,4))
df[df.Churn == "No"][numeric_feature].hist(bins=30,color="blue",alpha=0.5,ax=ax)
df[df.Churn == "Yes"][numeric_feature].hist(bins=30,color="red",alpha=0.5,ax=ax)

# %% [markdown]
# we look at distribution feature in reaktion to the target variable. we can observe that the greater TotalCharges and tenure are the less is the probability of churn

# %% [markdown]
# # Categorical_feature distribution
# To analyze categorical feature, we use bar chart. we observe that Senior citizen and customers without phone service are less represented in the data

# %%
# Assuming you have defined your DataFrame 'df'
ROWS, COLS = 4, 4
fig, ax = plt.subplots(ROWS, COLS, figsize=(19, 19))
row, col = 0, 0


for i, categorical_feature in enumerate(categorical_feature):
    if col == COLS-1:
        row += 1
        col = i % COLS
    
    
    df[categorical_feature].value_counts().plot(kind='bar', ax=ax[row, col])
    ax[row, col].set_title(categorical_feature)

# %% [markdown]
# The next step is to look at categorical feature in relation to the targeet variable. we do this only for contract feature. Users who have a month to month contract are more likely to churn than users with long term contract.

# %%
feature = 'Contract'

fig,ax=plt.subplots(1,2, figsize=(12, 4))

df[df.Churn=='No'][feature].value_counts().plot(kind='bar',ax=ax[0]).set_title('not churned')

df[df.Churn=='Yes'][feature].value_counts().plot(kind='bar',ax=ax[1]).set_title('churned')

# %% [markdown]
# # Target Variable Distribution

# %%
df[target].value_counts().plot(kind='bar').set_title('churned')

# %% [markdown]
# Target variable distribution shows that we are dealing with an imbalanced problem as there are many more non--churned as compare to churned users. The model would acheive high accuracy as it would mostly predict majority class -users who didn't churn in our example:
#
# Few Things we can do to minimize the influence of imbalance dataset:
#
# 1. Resample data
# 2. 2. collect more samples
#    3. use precision and recall as accuracy metrics.

# %% [markdown]
# # cleaning and Transforming Data

# %%
df.drop(['customerID'],axis=1,inplace=True)

# %%
df.head()

# %%
display(categorical_feature)

# %%
display(categorical_feature)

# %%
display(numeric_feature)

# %%
df1 = pd.get_dummies(data=df,columns=['gender', 'Partner', 'Dependents',
     'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn'],drop_first=True)

# %% [markdown]
# pd.get_dummies(data=df, columns=[...], drop_first=True): This is a Pandas function called get_dummies() used for one-hot encoding categorical variables. It converts categorical variables into dummy/indicator variables

# %% [markdown]
# columns=['gender', 'Partner', 'Dependents', ..., 'Churn']: This specifies the columns in the DataFrame df that need to be one-hot encoded.
#
# drop_first=True: This parameter is used to drop the first level of each categorical variable after encoding, which helps to avoid multicollinearity issues in some machine learning algorithms. For example, if a variable has n categories, after one-hot encoding, n-1 binary columns are created, and the dropped column represents the first category.

# %%
display(df1)

# %% [markdown]
# where churn is 0 it means 'No' where churn is 'YES'  it means 1

# %%
df1.head()

# %%
df1.shape
